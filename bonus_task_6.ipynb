# %% [markdown]
# # Optional Task 6 : Bonus Task

# %% [markdown]
# * Author: [Prabha Sapkota](https://github.com/prabhasapkota)
# * Repository: [datafun-05-data-at-rest](https://github.com/prabhasapkota/datafun-05-data-at-rest)
# * Date: 09-22-2023

# %% [markdown]
# ## Import libraries and csv DataFrames

# %%
import pandas as pd
iris = pd.read_csv("iris.csv")
iris
# Out:
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# 0             0           5.1          3.5           1.4          0.2
# 1             1           4.9          3.0           1.4          0.2
# 2             2           4.7          3.2           1.3          0.2
# 3             3           4.6          3.1           1.5          0.2
# 4             4           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         145           6.7          3.0           5.2          2.3
# 146         146           6.3          2.5           5.0          1.9
# 147         147           6.5          3.0           5.2          2.0
# 148         148           6.2          3.4           5.4          2.3
# 149         149           5.9          3.0           5.1          1.8
#
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %% [markdown]
# ## Using the DataFrame commandfs to update the columns

# %%
iris.columns = ["Unnamed", "sepal_length", "sepal_width", "petal_length", "petal_width", "species"]
iris.head()  # shows only top 5 datasets
# Out:
#    Unnamed  sepal_length  sepal_width  petal_length  petal_width species
# 0        0           5.1          3.5           1.4          0.2  setosa
# 1        1           4.9          3.0           1.4          0.2  setosa
# 2        2           4.7          3.2           1.3          0.2  setosa
# 3        3           4.6          3.1           1.5          0.2  setosa
# 4        4           5.0          3.6           1.4          0.2  setosa

# %%
iris = iris.drop(columns = ["sepal_width"]) # deleting the column which are not needed.
iris.head()
# Out:
#    Unnamed  sepal_length  petal_length  petal_width species
# 0        0           5.1           1.4          0.2  setosa
# 1        1           4.9           1.4          0.2  setosa
# 2        2           4.7           1.3          0.2  setosa
# 3        3           4.6           1.5          0.2  setosa
# 4        4           5.0           1.4          0.2  setosa

# %% [markdown]
# ## Using the DataFrame describe() function to calculate descriptive statistics

# %%
pd.set_option("display.precision", 2)
iris.describe()
# Out:
#        Unnamed  sepal_length  petal_length  petal_width
# count   150.00        150.00        150.00       150.00
# mean     74.50          5.84          3.76         1.20
# std      43.45          0.83          1.77         0.76
# min       0.00          4.30          1.00         0.10
# 25%      37.25          5.10          1.60         0.30
# 50%      74.50          5.80          4.35         1.30
# 75%     111.75          6.40          5.10         1.80
# max     149.00          7.90          6.90         2.50

# %% [markdown]
# ## Using the DataFrame hist() function to generate histograms

# %%
# %matplotlib inline
histogram = iris.hist()
